# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.model_selection import train_test_split

# %%
A = np.random.multivariate_normal([-3,3],[[1,0],[0,1]],100)
B = np.random.multivariate_normal([-3,-3],[[1,0],[0,1]],100)
X = np.vstack((A,B))
y = np.concatenate((np.repeat(-5,100),np.repeat(5,100)))

# %%
train = pd.DataFrame(X)
test = pd.DataFrame(y[:,None])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
model = RF(n_estimators = 100, max_depth = 2, random_state = 0)
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
model.predict(X_test) == y_test
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# ## Test

# %%
df = pd.DataFrame(X)
df.columns = ['x1', 'x2']
df2 = df.copy()
df2.columns = ['x3','x4']

# %%
pd.concat([df,df2],axis=1)
# Out:
#            x1        x2        x3        x4
# 0   -2.448281  2.069855 -2.448281  2.069855
# 1   -4.535908  4.522214 -4.535908  4.522214
# 2   -3.190698  2.428130 -3.190698  2.428130
# 3   -4.397345  1.792308 -4.397345  1.792308
# 4   -1.182119  3.005548 -1.182119  3.005548
# 5   -2.716582  3.131292 -2.716582  3.131292
# 6   -2.875083  2.565020 -2.875083  2.565020
# 7   -3.641523  2.595994 -3.641523  2.595994
# 8   -3.205864  1.937657 -3.205864  1.937657
# 9   -3.447095  4.610278 -3.447095  4.610278
# 10  -3.497677  3.355795 -3.497677  3.355795
# 11  -3.491191  2.946184 -3.491191  2.946184
# 12  -2.284490  2.812836 -2.284490  2.812836
# 13  -2.120554  3.845939 -2.120554  3.845939
# 14  -3.039305  3.513700 -3.039305  3.513700
# 15  -3.315424  4.741200 -3.315424  4.741200
# 16  -2.712901  1.560863 -2.712901  1.560863
# 17  -2.256749  1.348122 -2.256749  1.348122
# 18  -4.072723  2.919778 -4.072723  2.919778
# 19  -2.973400  3.353823 -2.973400  3.353823
# ...

# %%
df['id'] = np.linspace(1,200,200)
df2['id'] = np.linspace(1,200,200)

# %%
df = df.merge(df2, how='left', on='id')
df.assign(x1x2 = df.x1 * df.x2)
# Out:
#            x1        x2     id        x3        x4       x1x2
# 0   -2.448281  2.069855    1.0 -2.448281  2.069855  -5.067585
# 1   -4.535908  4.522214    2.0 -4.535908  4.522214 -20.512346
# 2   -3.190698  2.428130    3.0 -3.190698  2.428130  -7.747429
# 3   -4.397345  1.792308    4.0 -4.397345  1.792308  -7.881399
# 4   -1.182119  3.005548    5.0 -1.182119  3.005548  -3.552916
# 5   -2.716582  3.131292    6.0 -2.716582  3.131292  -8.506412
# 6   -2.875083  2.565020    7.0 -2.875083  2.565020  -7.374645
# 7   -3.641523  2.595994    8.0 -3.641523  2.595994  -9.453371
# 8   -3.205864  1.937657    9.0 -3.205864  1.937657  -6.211863
# 9   -3.447095  4.610278   10.0 -3.447095  4.610278 -15.892068
# 10  -3.497677  3.355795   11.0 -3.497677  3.355795 -11.737487
# 11  -3.491191  2.946184   12.0 -3.491191  2.946184 -10.285689
# 12  -2.284490  2.812836   13.0 -2.284490  2.812836  -6.425894
# 13  -2.120554  3.845939   14.0 -2.120554  3.845939  -8.155521
# ...
