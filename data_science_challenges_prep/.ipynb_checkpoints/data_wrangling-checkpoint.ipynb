# %%
import pandas as pd
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/weatherAUS.csv')

# %% [markdown]
# ## NAs

# %%
df = df.dropna(how='any')

# %% [markdown]
# ## Subsetting

# %%
df = df.loc[:,['Date','Location','MinTemp','MaxTemp','Evaporation','Sunshine','RainTomorrow']]
df.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 5939  2009-01-01    Cobar     17.9     35.2         12.0      12.3
# 5940  2009-01-02    Cobar     18.4     28.9         14.8      13.0
# 5942  2009-01-04    Cobar     19.4     37.6         10.8      10.6
# 5943  2009-01-05    Cobar     21.9     38.4         11.4      12.2
# 5944  2009-01-06    Cobar     24.2     41.0         11.2       8.4
#
#      RainTomorrow
# 5939           No
# 5940           No
# 5942           No
# 5943           No
# 5944           No

# %%
some_cities = ['Darwin','Perth','Brisbane','Mildura']
df_some_cities = df[df.Location.isin(some_cities)]
df_some_cities.head()
# Out:
#              Date Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 68180  2009-01-01  Mildura     13.8     27.4          9.6      12.6
# 68182  2009-01-03  Mildura     10.6     28.6          9.2      13.6
# 68183  2009-01-04  Mildura     13.2     34.5          8.8      13.5
# 68184  2009-01-05  Mildura     16.5     37.3         10.4      13.4
# 68185  2009-01-06  Mildura     15.7     39.2         13.4      13.4
#
#       RainTomorrow
# 68180           No
# 68182           No
# 68183           No
# 68184           No
# 68185           No

# %%
df_low_min = df[df.MinTemp < 10]
df_low_min.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 6013  2009-03-16    Cobar      9.2     24.4          7.6      10.9
# 6033  2009-04-05    Cobar      9.9     24.6          7.0      11.2
# 6035  2009-04-07    Cobar      9.4     25.6          7.6      11.2
# 6055  2009-04-27    Cobar      5.7     19.7          4.8      10.3
# 6057  2009-04-29    Cobar      6.2     17.0          4.0       9.6
#
#      RainTomorrow
# 6013           No
# 6033           No
# 6035           No
# 6055           No
# 6057           No

# %% [markdown]
# ## Date

# %%
df.Date = pd.to_datetime(df.Date)
df['Week'] = df.Date.dt.week
df['Month'] = df.Date.dt.month
df['Year'] = df.Date.dt.year

# %% [markdown]
# ## Group By

# %%
df_summary = df.groupby('Location').agg({'MinTemp':'mean',
                            'MaxTemp':'mean',
                            'Date':'count'
                           }).reset_index()

# %%
df_summary = df_summary.rename(columns={'MinTemp':'LocMinTemp',
                           'MaxTemp':'LocMaxTemp',
                           'Date':'Count'})

# %%
df_summary.head()
# Out:
#        Location  LocMinTemp  LocMaxTemp  Count
# 0  AliceSprings   13.878093   29.724921   2223
# 1      Brisbane   16.365628   26.436810   2953
# 2        Cairns   21.129296   29.551596   2444
# 3      Canberra    7.727829   20.363822   1078
# 4         Cobar   13.828090   26.225281    534

# %% [markdown]
# ## Join

# %%
df_merged = df.merge(df_summary, on='Location', how='left')
df_merged.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Evaporation  Sunshine  RainTomorrow  \
# 0 2009-01-01    Cobar     17.9     35.2         12.0      12.3             0
# 1 2009-01-02    Cobar     18.4     28.9         14.8      13.0             0
# 2 2009-01-04    Cobar     19.4     37.6         10.8      10.6             0
# 3 2009-01-05    Cobar     21.9     38.4         11.4      12.2             0
# 4 2009-01-06    Cobar     24.2     41.0         11.2       8.4             0
#
#    Week  Month  Year  LocMinTemp  LocMaxTemp  Count
# 0     1      1  2009    13.82809   26.225281    534
# 1     1      1  2009    13.82809   26.225281    534
# 2     1      1  2009    13.82809   26.225281    534
# 3     2      1  2009    13.82809   26.225281    534
# 4     2      1  2009    13.82809   26.225281    534

# %% [markdown]
# ## Concat

# %%
df_1 = df.iloc[0:100,:]
df_2 = df.iloc[100:200,:]
df_concat = pd.concat([df_1,df_2],axis=0)

# %% [markdown]
# ## Transform Covariates

# %%
## apply

def to_farenheit(C):
    return ((9/5)*C)+32

df_faren = df[['MinTemp','MaxTemp']].apply(to_farenheit)
df_temps = pd.concat([df[['MinTemp','MaxTemp']],df_faren],axis=1)
df_temps.columns = [x+'C' for x in ['MinTemp','MaxTemp']] + [x+'F' for x in ['MinTemp','MaxTemp']]
df_temps.head()
# Out:
#       MinTempC  MaxTempC  MinTempF  MaxTempF
# 5939      17.9      35.2     64.22     95.36
# 5940      18.4      28.9     65.12     84.02
# 5942      19.4      37.6     66.92     99.68
# 5943      21.9      38.4     71.42    101.12
# 5944      24.2      41.0     75.56    105.80

# %%
## map
binary_outcome = {'Yes':1, 'No':0}
df.RainTomorrow = df.RainTomorrow.map(binary_outcome)

# %%
df.Month.value_counts()
# Out:
# 1     5267
# 3     5174
# 5     4896
# 10    4811
# 8     4728
# 11    4717
# 7     4709
# 9     4638
# 6     4565
# 4     4422
# 12    4264
# 2     4229
# Name: Month, dtype: int64

# %%
## zscore
from scipy.stats import zscore
MinTemp_zscore = zscore(df.MinTemp)
np.histogram(MinTemp_zscore)
# Out:
# (array([   53,   849,  3934,  9239, 11544, 10991,  9410,  6847,  3387,
#           166]),
#  array([-3.14257851, -2.54880906, -1.95503961, -1.36127016, -0.76750071,
#         -0.17373127,  0.42003818,  1.01380763,  1.60757708,  2.20134653,
#          2.79511598]))

# %% [markdown]
# ## Reshape

# %%
df.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Evaporation  Sunshine  \
# 5939  2009-01-01    Cobar     17.9     35.2         12.0      12.3
# 5940  2009-01-02    Cobar     18.4     28.9         14.8      13.0
# 5942  2009-01-04    Cobar     19.4     37.6         10.8      10.6
# 5943  2009-01-05    Cobar     21.9     38.4         11.4      12.2
# 5944  2009-01-06    Cobar     24.2     41.0         11.2       8.4
#
#       RainTomorrow
# 5939             0
# 5940             0
# 5942             0
# 5943             0
# 5944             0

# %%
df['Season'] = (df.Month%12 + 3)//3
df_season = df.groupby(['Location','Season'])[['MinTemp']].mean().reset_index()
df_season.head()
# Out:
#        Location  Season    MinTemp
# 0  AliceSprings       1  20.847245
# 1  AliceSprings       2  13.461041
# 2  AliceSprings       3   5.119798
# 3  AliceSprings       4  14.565385
# 4      Brisbane       1  21.235242

# %%
## Pivot Table

df_season2 = df_season.pivot(index='Location', columns='Season', values='MinTemp')
df_season2.head()
# Out:
# Season                1          2          3          4
# Location
# AliceSprings  20.847245  13.461041   5.119798  14.565385
# Brisbane      21.235242  17.301103  11.237760  16.293453
# Cairns        23.946405  21.974756  17.848950  20.774290
# Canberra      13.668966   7.684026   1.883333   7.473413
# Cobar         20.907692  13.536471   6.551111  14.055814

# %%
df_season2.head()
# Out:
# Season      Location          1          2          3          4
# 0       AliceSprings  20.847245  13.461041   5.119798  14.565385
# 1           Brisbane  21.235242  17.301103  11.237760  16.293453
# 2             Cairns  23.946405  21.974756  17.848950  20.774290
# 3           Canberra  13.668966   7.684026   1.883333   7.473413
# 4              Cobar  20.907692  13.536471   6.551111  14.055814
